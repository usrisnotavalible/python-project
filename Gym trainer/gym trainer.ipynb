# %%
'''

                    Creating a Gym Exercise and Diet System to make people Fit and Healthy



'''





from datetime import datetime 



print("Welcome to Gym")



print("Who are you")

print("1:Amir  2:Saad")

n = int(input())



print("What You want")

print("I:input O:Output")       #input to take data in and output to show the success level of diet and exercise

e = input()



print("What you want to see")

print("E:Exercise D:Diet")

d = input()



def get_time():             #Use datetime function here

    import datetime

    return datetime.datetime.now()





#It will add the data to the file

if n==1:                                   

    if e == "I":          

        if d == "E":

            print()

            print()

            print("What You want to add:")

            z_0 = input()#used different name like z_0,z_a,z_b

            print("Added")

            with open("Amir.txt","w") as f:

                time = str(get_time())

                f.write(z_0+"[" + time+"]"+"\n" )



                

#It will give the Output                

if n==1:    

    if e =="O":

        if d == "E":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Amir.txt") as g:

                content = g.readline()

                print(content)

#It will add the data to the file 

if n==1:

    if e == "I":

        if d == "D":

            print()

            print()

            print("What You want to add:")

            z_a = input()

            print("Added")

            with open("Amir.txt","w") as f:

                time = str(get_time())

                f.write(z_a+"[" + time+"]"+"\n" )

#It will give the Output        

if n==1:

    if e =="O":

        if d == "D":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Amir.txt") as g:

                content = g.readline()

                print(content)

#--------------------------------------Person 2 start file here---------------------------------------------              



#It will add the data to the file

if n==2:

    if e == "I":

        if d == "E":

            print()

            print()

            print("What You want to add:")

            z_b = input()

            print("Added")

            with open("Saad.txt","w") as f:

                time = str(get_time)

                f.write(z_b+"[" + time+"]" +"\n")



#It will give the Output                        

if n==2:

    if e =="O":

        if d == "E":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Saad.txt") as g:

                content = g.readline()

                print(content)



#It will add the data to the file                

if n==2:

    if e == "I":

        if d == "D":

            print()

            print()

            print("What You want to add:")

            z_c = input()

            print("Added")

            with open("Saad.txt","w") as f:

                time = str(get_time)

                f.write(z_c+"[" + time+"]"+"\n" )

#It will give the Output        

if n==2:

    if e =="O":

        if d == "D":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Saad.txt") as g:

                content = g.readline()

                print(content)

                

                

#--------------------------------------program End Here------------------------------------------

'''

        Here i use 2 person as an example but you can add as much as you want multiple persons can be added 

to it.You can also copy this program tnx me later 



''''''

                    Creating a Gym Exercise and Diet System to make peole Fit and Healthy



'''





from datetime import datetime 



print("Welcome to Gym")



print("Who are you")

print("1:Amir  2:Saad")

n = int(input())



print("What You want")

print("I:input O:Output")       #input to take data in and output to show the success level of diet and exercise

e = input()



print("What you want to see")

print("E:Exercise D:Diet")

d = input()



def get_time():             #Use datetime function here

    import datetime

    return datetime.datetime.now()





#It will add the data to the file

if n==1:                                   

    if e == "I":          

        if d == "E":

            print()

            print()

            print("What You want to add:")

            z_0 = input()#used different name like z_0,z_a,z_b

            print("Added")

            with open("Amir.txt","w") as f:

                time = str(get_time())

                f.write(z_0+"[" + time+"]"+"\n" )



                

#It will give the Output                

if n==1:    

    if e =="O":

        if d == "E":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Amir.txt") as g:

                content = g.readline()

                print(content)

#It will add the data to the file 

if n==1:

    if e == "I":

        if d == "D":

            print()

            print()

            print("What You want to add:")

            z_a = input()

            print("Added")

            with open("Amir.txt","w") as f:

                time = str(get_time())

                f.write(z_a+"[" + time+"]"+"\n" )

#It will give the Output        

if n==1:

    if e =="O":

        if d == "D":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Amir.txt") as g:

                content = g.readline()

                print(content)

#--------------------------------------Person 2 start file here---------------------------------------------              



#It will add the data to the file

if n==2:

    if e == "I":

        if d == "E":

            print()

            print()

            print("What You want to add:")

            z_b = input()

            print("Added")

            with open("Saad.txt","w") as f:

                time = str(get_time)

                f.write(z_b+"[" + time+"]" +"\n")



#It will give the Output                        

if n==2:

    if e =="O":

        if d == "E":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Saad.txt") as g:

                content = g.readline()

                print(content)



#It will add the data to the file                

if n==2:

    if e == "I":

        if d == "D":

            print()

            print()

            print("What You want to add:")

            z_c = input()

            print("Added")

            with open("Saad.txt","w") as f:

                time = str(get_time)

                f.write(z_c+"[" + time+"]"+"\n" )

#It will give the Output        

if n==2:

    if e =="O":

        if d == "D":

            print()

            print()

            print()

            print("Your Out is Here")

            with open("Saad.txt") as g:

                content = g.readline()

                print(content)

                

                

#--------------------------------------program End Here------------------------------------------

'''

        Here i use 2 person as an example but you can add as much as you want multiple persons can be added 

to it.You can also copy this program tnx me later 



'''
